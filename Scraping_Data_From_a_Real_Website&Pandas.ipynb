# %% [markdown]
# <a href="https://colab.research.google.com/github/yuliatun/Python-EXCERCISE/blob/master/Scraping_Data_From_a_Real_Website%26Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scraping Data From a Real Website + Pandas

# %%
# !pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup
import requests

url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_by_revenue'

# Menambahkan headers supaya request tidak diblokir
headers = {"User-Agent": "Mozilla/5.0"}
page = requests.get(url, headers=headers)

soup = BeautifulSoup(page.text,'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of largest companies by revenue - Wikipedia</title>
# ...

# %%
soup.find_all('table')
# Out:
# [<table class="wikitable sortable sticky-header-multi sort-under" style="text-align:left;">
#  <tbody><tr>
#  <th rowspan="2" scope="col">Ranks
#  </th>
#  <th rowspan="2" scope="col">Name
#  </th>
#  <th rowspan="2" scope="col">Industry
#  </th>
#  <th scope="col">Revenue
#  </th>
#  <th scope="col">Profit
#  </th>
#  <th rowspan="2" scope="col">Employees
#  </th>
#  <th rowspan="2" scope="col">Headquarters<sup class="reference" id="cite_ref-4"><a href="#cite_note-4"><span class="cite-bracket">[</span>note 1<span class="cite-bracket">]</span></a></sup>
#  </th>
#  <th rowspan="2" scope="col"><a href="/wiki/State-owned_enterprise" title="State-owned enterprise">State-owned</a>
#  </th>
#  <th class="unsortable" rowspan="2" scope="col"><abbr title="Reference(s)">Ref.</abbr>
#  </th></tr>
#  <tr>
#  <th colspan="2" scope="col"><small>USD (in millions)</small>
#  </th></tr>
#  <tr>
#  <th scope="col">1
#  </th>
#  <td><a href="/wiki/Walmart" title="Walmart">Walmart</a></td>
# ...

# %%
soup.find_all('table')[0]
# Out:
# <table class="wikitable sortable sticky-header-multi sort-under" style="text-align:left;">
# <tbody><tr>
# <th rowspan="2" scope="col">Ranks
# </th>
# <th rowspan="2" scope="col">Name
# </th>
# <th rowspan="2" scope="col">Industry
# </th>
# <th scope="col">Revenue
# </th>
# <th scope="col">Profit
# </th>
# <th rowspan="2" scope="col">Employees
# </th>
# <th rowspan="2" scope="col">Headquarters<sup class="reference" id="cite_ref-4"><a href="#cite_note-4"><span class="cite-bracket">[</span>note 1<span class="cite-bracket">]</span></a></sup>
# </th>
# <th rowspan="2" scope="col"><a href="/wiki/State-owned_enterprise" title="State-owned enterprise">State-owned</a>
# </th>
# <th class="unsortable" rowspan="2" scope="col"><abbr title="Reference(s)">Ref.</abbr>
# </th></tr>
# <tr>
# <th colspan="2" scope="col"><small>USD (in millions)</small>
# </th></tr>
# <tr>
# <th scope="col">1
# </th>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a></td>
# ...

# %%
table = soup.find_all('table')[1]

# %%
print(table)
# Out:
# <table class="wikitable sortable sticky-header-multi sort-under" style="text-align:left;">
# <tbody><tr>
# <th rowspan="2" scope="col">Ranks
# </th>
# <th rowspan="2" scope="col">Name
# </th>
# <th rowspan="2" scope="col">Industry
# </th>
# <th scope="col">Revenue
# </th>
# <th scope="col">Profit
# </th>
# <th rowspan="2" scope="col">Employees
# </th>
# <th rowspan="2" scope="col">Headquarters<sup class="reference" id="cite_ref-4"><a href="#cite_note-4"><span class="cite-bracket">[</span>note 1<span class="cite-bracket">]</span></a></sup>
# </th>
# <th rowspan="2" scope="col"><a href="/wiki/State-owned_enterprise" title="State-owned enterprise">State-owned</a>
# </th>
# <th class="unsortable" rowspan="2" scope="col"><abbr title="Reference(s)">Ref.</abbr>
# </th></tr>
# <tr>
# <th colspan="2" scope="col"><small>USD (in millions)</small>
# </th></tr>
# <tr>
# <th scope="col">1
# </th>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a></td>
# ...

# %%
world_titles = table.find_all('th')

# %%
world_titles
# Out:
# [<th class="unsortable" scope="col">Rank
#  </th>,
#  <th scope="col">Country
#  </th>,
#  <th scope="col">Companies
#  </th>,
#  <th scope="row">1
#  </th>,
#  <th scope="row">2
#  </th>,
#  <th scope="row">3
#  </th>,
#  <th scope="row">4
#  </th>,
#  <th scope="row">4
#  </th>,
#  <th scope="row">5
#  </th>,
#  <th scope="row">5
#  </th>,
#  <th scope="row">5
#  </th>,
#  <th scope="row">5
#  </th>,
#  <th scope="row">5
#  </th>,
#  <th scope="row">5
#  </th>,
#  <th scope="row">5
#  </th>,
#  <th scope="row">5
#  </th>]

# %%
world_table_titles = [th.text.strip() for th in table.find('tr').find_all('th')]
print (world_table_titles)
# Out:
# ['Rank', 'Country', 'Companies']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = world_table_titles)
df
# Out:
# Empty DataFrame
# Columns: [Rank, Country, Companies]
# Index: []

# %%
column_data = table.find_all('tr')

# %%
for row in column_data[2:]:
 row_data = row.find_all(['td', 'th'])
 individual_row_data = [cell.text.strip() for cell in row_data]
 print(individual_row_data)
 length = len(df)
 df.loc[length] = individual_row_data
#   # Jika jumlah sel tidak sama dengan jumlah kolom, tambahkan None untuk menyesuaikan
#  while len(individual_row_data) < len(df.columns):
#         individual_row_data.append(None)
#  df.loc[len(df)] = individual_row_data
# Out:
# ['2', 'China', '11']
# ['3', 'Germany', '4']
# ['4', 'United Kingdom', '2']
# ['4', 'Switzerland', '2']
# ['5', 'Japan', '1']
# ['5', 'France', '1']
# ['5', 'Italy', '1']
# ['5', 'Netherlands', '1']
# ['5', 'South Korea', '1']
# ['5', 'Saudi Arabia', '1']
# ['5', 'Singapore', '1']
# ['5', 'Taiwan', '1']

# %%
df
# Out:
#    Rank         Country Companies
# 0     2           China        11
# 1     3         Germany         4
# 2     4  United Kingdom         2
# 3     4     Switzerland         2
# 4     5           Japan         1
# 5     5          France         1
# 6     5           Italy         1
# 7     5     Netherlands         1
# 8     5     South Korea         1
# 9     5    Saudi Arabia         1
# 10    5       Singapore         1
# 11    5          Taiwan         1

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_by_revenue'
headers = {"User-Agent": "Mozilla/5.0"}
page = requests.get(url, headers=headers)
soup = BeautifulSoup(page.text, 'html.parser')

table = soup.find('table', {"class": "wikitable"})

# Ambil header
header_row = table.find('tr')
headers = [th.text.strip() for th in header_row.find_all(['th','td'])]

# Buat DataFrame kosong dengan header
df = pd.DataFrame(columns=headers)

# Loop baris
rows = table.find_all('tr')[2:]  # skip header
for row in rows:
    cells = row.find_all(['td','th'])
    row_data = [cell.text.strip() for cell in cells]

    # Jika jumlah sel tidak sama dengan jumlah kolom, tambahkan None untuk menyesuaikan
    while len(row_data) < len(df.columns):
        row_data.append(None)
    df.loc[len(df)] = row_data

df
# Out:
#    Ranks                                     Name  \
# 0      1                                  Walmart
# 1      2                                   Amazon
# 2      3          State Grid Corporation of China
# 3      4                             Saudi Aramco
# 4      5          China Petrochemical Corporation
# 5      6     China National Petroleum Corporation
# 6      7                       UnitedHealth Group
# 7      8                                    Apple
# 8      9                       Berkshire Hathaway
# 9     10                               CVS Health
# 10    11                                 Alphabet
# 11    12                         Volkswagen Group
# 12    13                               ExxonMobil
# 13    14                                    Vitol
# 14    15                                    Shell
# 15    16     China State Construction Engineering
# 16    17                                   Toyota
# 17    18                                 McKesson
# ...
